# %%
import pandas as pd

# %%
df = pd.read_csv("dataset_SCL.csv")
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13264\1100006479.py:1: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("dataset_SCL.csv")

# %%
df
# Out:
#                    Fecha-I Vlo-I Ori-I Des-I Emp-I              Fecha-O  \
# 0      2017-01-01 23:30:00   226  SCEL  KMIA   AAL  2017-01-01 23:33:00
# 1      2017-01-02 23:30:00   226  SCEL  KMIA   AAL  2017-01-02 23:39:00
# 2      2017-01-03 23:30:00   226  SCEL  KMIA   AAL  2017-01-03 23:39:00
# 3      2017-01-04 23:30:00   226  SCEL  KMIA   AAL  2017-01-04 23:33:00
# 4      2017-01-05 23:30:00   226  SCEL  KMIA   AAL  2017-01-05 23:28:00
# ...                    ...   ...   ...   ...   ...                  ...
# 68201  2017-12-22 14:55:00   400  SCEL  SPJC   JAT  2017-12-22 15:41:00
# 68202  2017-12-25 14:55:00   400  SCEL  SPJC   JAT  2017-12-25 15:11:00
# 68203  2017-12-27 14:55:00   400  SCEL  SPJC   JAT  2017-12-27 15:35:00
# 68204  2017-12-29 14:55:00   400  SCEL  SPJC   JAT  2017-12-29 15:08:00
# 68205  2017-12-31 14:55:00   400  SCEL  SPJC   JAT  2017-12-31 15:04:00
#
#        Vlo-O Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# ...

# %% [markdown]
# # Gráfico de Distribución de variables numéricas

# %%
df.hist(figsize=(40, 40), bins=30, xlabelsize=20, ylabelsize=20);

# %% [markdown]
# ### Los datos tienen una distribución uniforme. Para el caso de los días, se puede apreciar que hay una tendencia a realizar vuelos el último día del mes. Además se puede apreciar que en general hay una diferencia de 1000 vuelos en la temporada de vacaciones, tanto de verano como de invierno.

# %% [markdown]
# # Synthetic Features

# %%
synthetic_features = df.copy()

# %%
synthetic_features
# Out:
#                    Fecha-I Vlo-I Ori-I Des-I Emp-I              Fecha-O  \
# 0      2017-01-01 23:30:00   226  SCEL  KMIA   AAL  2017-01-01 23:33:00
# 1      2017-01-02 23:30:00   226  SCEL  KMIA   AAL  2017-01-02 23:39:00
# 2      2017-01-03 23:30:00   226  SCEL  KMIA   AAL  2017-01-03 23:39:00
# 3      2017-01-04 23:30:00   226  SCEL  KMIA   AAL  2017-01-04 23:33:00
# 4      2017-01-05 23:30:00   226  SCEL  KMIA   AAL  2017-01-05 23:28:00
# ...                    ...   ...   ...   ...   ...                  ...
# 68201  2017-12-22 14:55:00   400  SCEL  SPJC   JAT  2017-12-22 15:41:00
# 68202  2017-12-25 14:55:00   400  SCEL  SPJC   JAT  2017-12-25 15:11:00
# 68203  2017-12-27 14:55:00   400  SCEL  SPJC   JAT  2017-12-27 15:35:00
# 68204  2017-12-29 14:55:00   400  SCEL  SPJC   JAT  2017-12-29 15:08:00
# 68205  2017-12-31 14:55:00   400  SCEL  SPJC   JAT  2017-12-31 15:04:00
#
#        Vlo-O Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# ...

# %%
synthetic_features = df.copy()
synthetic_features['Fecha-I'] =  pd.to_datetime(synthetic_features['Fecha-I'], format='%Y-%m-%d %H:%M:%S')
synthetic_features['Fecha-O'] =  pd.to_datetime(synthetic_features['Fecha-O'], format='%Y-%m-%d %H:%M:%S')
synthetic_features
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
# ...

# %%
synthetic_features['high_season'] = synthetic_features.apply(lambda row: 1 if ((row['Fecha-I'] >= pd.Timestamp(2016,12,15) and row['Fecha-I'] <= pd.Timestamp(2017,3,3)) or 
                                                                               (row['Fecha-I'] >= pd.Timestamp(2017,7,15) and row['Fecha-I'] <= pd.Timestamp(2017,7,31)) or 
                                                                               (row['Fecha-I'] >= pd.Timestamp(2017,9,11) and row['Fecha-I'] <= pd.Timestamp(2017,9,30)) or
                                                                               (row['Fecha-I'] >= pd.Timestamp(2017,12,15) and row['Fecha-I'] <= pd.Timestamp(2018,3,3))) else 0, axis=1)

# %%
synthetic_features
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
# ...

# %%
synthetic_features['min_diff'] = synthetic_features.apply(lambda row: (row['Fecha-O'] - row['Fecha-I']).total_seconds() / 60, axis=1)

# %%
synthetic_features
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
# ...

# %%
synthetic_features['delay_15'] = synthetic_features.apply(lambda row: 1 if (row['min_diff'] > 15) else 0, axis=1)

# %%
def check_period_day(date):
    # morning: 5:00 and 11:59 
    if date.hour >= 5 and date.hour < 12:
        return "morning"
    # afternoon (between 12:00 and 18:59)
    elif date.hour >= 12 and date.hour < 19:
        return "afternoon"
    else:
        return "night"

# %%
synthetic_features['period_day'] = synthetic_features.apply(lambda row: check_period_day(row['Fecha-I']), axis=1)

# %%
synthetic_features
# Out:
#                   Fecha-I Vlo-I Ori-I Des-I Emp-I             Fecha-O  Vlo-O  \
# 0     2017-01-01 23:30:00   226  SCEL  KMIA   AAL 2017-01-01 23:33:00    226
# 1     2017-01-02 23:30:00   226  SCEL  KMIA   AAL 2017-01-02 23:39:00    226
# 2     2017-01-03 23:30:00   226  SCEL  KMIA   AAL 2017-01-03 23:39:00    226
# 3     2017-01-04 23:30:00   226  SCEL  KMIA   AAL 2017-01-04 23:33:00    226
# 4     2017-01-05 23:30:00   226  SCEL  KMIA   AAL 2017-01-05 23:28:00    226
# ...                   ...   ...   ...   ...   ...                 ...    ...
# 68201 2017-12-22 14:55:00   400  SCEL  SPJC   JAT 2017-12-22 15:41:00  400.0
# 68202 2017-12-25 14:55:00   400  SCEL  SPJC   JAT 2017-12-25 15:11:00  400.0
# 68203 2017-12-27 14:55:00   400  SCEL  SPJC   JAT 2017-12-27 15:35:00  400.0
# 68204 2017-12-29 14:55:00   400  SCEL  SPJC   JAT 2017-12-29 15:08:00  400.0
# 68205 2017-12-31 14:55:00   400  SCEL  SPJC   JAT 2017-12-31 15:04:00  400.0
#
# ...
